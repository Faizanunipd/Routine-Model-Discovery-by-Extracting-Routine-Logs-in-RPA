# %% [markdown]
# ## *import libraries*

# %%
import functions as f

import os
import re
import numpy as np
import pandas as pd
from tabulate import tabulate
from scipy.spatial.distance import cdist

import pm4py
from pm4py.algo.evaluation import algorithm
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.algo.conformance.tokenreplay import algorithm as token_replay
from pm4py.objects.petri_net.importer.variants import pnml as pnml_importer
from pm4py.algo.conformance.alignments.petri_net import algorithm as alignments

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Parameter Setting*

# %%
# log_number = 6
# noise_prob = 0.2

# if noise_prob == 0:
#     log_path = f"Transformed_Logs_and_Results/Our/Transformed_Log_Without_Noise/transform_log{log_number}.xes"
#     routines_file_path = f"Transformed_Logs_and_Results/Simon/Transformed_Log_Without_Noise/Discovered_Routines/simon_noisy_transform_log{log_number}_.txt"
# else:
#     log_path = f"Transformed_Logs_and_Results/Our/Transformed_Log_With_Noise_{noise_prob}/noisy_transform_log{log_number}.xes"
#     routines_file_path = f"Transformed_Logs_and_Results/Simon/Transformed_Log_With_Noise_{noise_prob}/Discovered_Routines/simon_noisy_transform_log{log_number}_.txt"

# cpn_ground_truth_dir = f"GT_Models/log{log_number}/"

# key_value = 1

# %% [markdown]
# ## *Read Log and Discovered Routines*

# %%
def UI_read_log(log_path):
    # Load event log
    log = f.read_log(log_path)
    
    # Define activities in the reference set
    reference_set = list(log['concept:name'].unique())

    return log, reference_set

# %%
def read_routines(routines_path):
    all_routines = []
    # Open the text file and read line by line
    with open(routines_path, "r") as file:
        for line in file:
            # Split the line into parts (splits by spaces by default)
            parts = line.strip().split()
            
            # Exclude the last item (supporting number) and store the routine list
            routine = parts[:-1]  # This excludes the last element
            all_routines.append(routine)  # Add the routine to the main list
    return all_routines

# %% [markdown]
# ## *Prepare encoding of discovered routines*

# %%
def get_discover_routines_encoding(all_routines, reference_set):
    routines = dict()
    
    # Iterate over the sequences
    for i, sequence in enumerate(all_routines):
        # Define a unique routine name for each sequence
        routine_name = f"pattern{i+1}"
        # Convert the sequence into a set of unique activities
        routines[routine_name] = sequence
    
    # routine_vectors = {name: [1 if act in routine else 0 for act in reference_set] for name, routine in routines.items()}
    routine_vectors = {name: [routine.count(act) for act in reference_set] for name, routine in routines.items()}
    return routine_vectors, routines

# %% [markdown]
# ## *Prepare encoding of traces*

# %%
def freq_encoding(session_log):
    # Perform one-hot encoding
    one_hot_encoded = pd.get_dummies(session_log['concept:name'])
    
    # Replace frequency with 1 where frequency is not 0
    one_hot_encoded = one_hot_encoded.applymap(lambda x:x if x > 0 else 0)
    
    if 'lifecycle:transition' in session_log.columns:
        df_encoded = pd.concat([session_log[['case:concept:name', 'lifecycle:transition', 'Session']], one_hot_encoded], axis=1)
        df_grouped = df_encoded.groupby(['case:concept:name', 'lifecycle:transition', 'Session']).sum().reset_index()
    else:
        df_encoded = pd.concat([session_log[['case:concept:name', 'Session']], one_hot_encoded], axis=1)
        df_grouped = df_encoded.groupby(['case:concept:name', 'Session']).sum().reset_index()

    return df_grouped


def assign_labels_by_distance(encoded_log, encoded_vectors, reference_set):

    # Convert the encoded vectors to a DataFrame for easier computation
    vector_labels = list(encoded_vectors.keys())
    vector_values = np.array(list(encoded_vectors.values()), dtype=float)

    # enc_log = encoded_log[reference_set]
    
    # Compute distances for each row in the log
    enc_log = encoded_log[reference_set].astype(float)
    distances = np.linalg.norm(enc_log.values[:, None] - vector_values, axis=2)
    
    # Find the index of the minimum distance for each sample
    min_distance_indices = np.argmin(distances, axis=1)
    
    # Map the indices to vector labels
    assigned_labels = [vector_labels[idx] for idx in min_distance_indices]
    
    # Add the assigned labels to the log
    encoded_log['pattern_label'] = assigned_labels
    return encoded_log

# %% [markdown]
# ## *Assign Patterns to Traces*

# %%
def assign_pattern_to_traces(session_log, cluster_log):

    cluster_column = 'pattern_label'


    if 'lifecycle:transition' in session_log.columns:
        # Perform inner join
        merged_log = pd.merge(session_log, cluster_log, on=['case:concept:name', 'Session', 'lifecycle:transition'], how='inner')
        merged_log = merged_log[['case:concept:name', 'Session', 'lifecycle:transition', 'time:timestamp', 'concept:name', cluster_column]]
    else:
        # Perform inner join
        merged_log = pd.merge(session_log, cluster_log, on=['case:concept:name', 'Session'], how='inner')
        merged_log = merged_log[['case:concept:name', 'Session', 'time:timestamp', 'concept:name', cluster_column]]

    merged_log = merged_log.sort_values(by=['case:concept:name', 'Session', 'time:timestamp'])

    activity_log = merged_log[['case:concept:name', 'time:timestamp','concept:name', cluster_column]]

    return activity_log

# %% [markdown]
# ## *Evaluation Functions*

# %%
# Extract transitions (activities) from both models to calculate Jaccard Coefficient
def extract_transitions(net):
    """ Extracts the transitions (activities) from the given Petri net model. """
    return {t.label for t in net.transitions if t.label is not None}


def get_fScore(fitness, precision):
    if fitness+precision == 0:
        return 0
    f_score = (2*fitness*precision)/(fitness+precision)
    return f_score


def get_JC(net, im, fm, routine_label):
    gt_routine_activities = extract_transitions(net)
    routine_activities = set(routines[routine_label])
    # print(f"Ground Truth Activities: {gt_routine_activities}\n")
    # print(f"Discovered Activities: {routine_activities}\n")

    # Calculate the Jaccard Coefficient (Intersection over Union)
    intersection = routine_activities.intersection(gt_routine_activities)
    union = routine_activities.union(gt_routine_activities)
    jaccard_coefficient = len(intersection) / len(union)

    return jaccard_coefficient


def token_base_evaluation(log, net, im, fm):
    replayed_traces = token_replay.apply(log, net, im, fm)
    
    # Calculate Support (fraction of transitions supported by the log)
    activated_transitions = set()
    for trace in replayed_traces:
        for trans in trace['activated_transitions']:
            if trans is not None:  # Ensure the transition is valid
                activated_transitions.add(trans)
    total_transitions = len(net.transitions)
    support = len(activated_transitions) / total_transitions

    # Calculate Coverage
    covered_traces = sum([1 for trace in replayed_traces if trace['activated_transitions']])
    total_traces = len(log)
    coverage = covered_traces / total_traces

    return support, coverage
    

def alignment_base_evaluation(log, net, im, fm):
    # Apply alignment-based conformance checking
    aligned_traces = alignments.apply_log(log, net, im, fm)
    
    # Calculate Support (fraction of transitions supported by the log)
    activated_transitions = set()
    for trace in aligned_traces:
        for step in trace['alignment']:
            # Check if the step corresponds to a 'model move' (indicating a supported transition)
            if step[0] == step[1] and step[1] is not None:
                activated_transitions.add(step[1])
    total_transitions = len(net.transitions)
    support = len(activated_transitions) / total_transitions
    
    # Calculate Coverage (fraction of traces covered by at least one activated transition)
    covered_traces = sum(1 for trace in aligned_traces if any(step[0] == step[1] and step[1] is not None for step in trace['alignment']))
    total_traces = len(log)
    coverage = covered_traces / total_traces

    return support, coverage


def evaluate_routines(log, net, im, fm, token_base, routine_label):
    gt_routine_activities = extract_transitions(net)
    pattern_activities = set(routines[routine_label])

    case_id = log['case:concept:name'].unique()[0]
    routine_length = len(log[log['case:concept:name'] == case_id])

    # Calculate the Jaccard Coefficient (Intersection over Union)
    intersection = pattern_activities.intersection(gt_routine_activities)
    union = pattern_activities.union(gt_routine_activities)
    jc = len(intersection) / len(union)

    log = pm4py.convert_to_event_log(log)
    support, coverage = token_base_evaluation(log, net, im, fm) if token_base else alignment_base_evaluation(log, net, im, fm)

    # Calculate fitness, precision, generalization, and F-score
    q_o = algorithm.apply(log, net, im, fm)
    fitness = round(q_o['fitness']['average_trace_fitness'],3)
    prec = round(q_o['precision'],3)
    gen = round(q_o['generalization'],3)
    simp = round(q_o['simplicity'],3)
    f_score = get_fScore(fitness, prec)

    # # Print metrics
    # print("\nEvaluation Scores:")
    # print("=====================")
    # print("Fitness: ", fitness)
    # print("Precision: ", prec)
    # print("Generalization: ", gen)
    # print("Simplicity: ", simp)
    
    # print(f"\nCoverage: {coverage:.2f}")
    # print(f"Support: {support:.2f}")
    # print(f"Jaccard Coefficient: {jc:.2f}")

    return [routine_label, len(log), len(routines[routine_label]), fitness, prec, gen, simp, f_score, coverage, support, jc]

# %% [markdown]
# ## *Prepare Penalized Traces*

# %%
# # Iterate over traces and process activities
# def penalize_trace(trace, pattern_activities):
#     trace['concept:name'] = trace['concept:name'].apply(
#         lambda x: f"extra_{x}" if x not in pattern_activities else x
#     )
#     return trace

def routines_evaluate(activity_log, routine_vectors, routines):
    key_value = 1
    for pattern_label in routine_vectors.keys():
        fitted_traces = activity_log[activity_log['pattern_label'] == pattern_label]
        # fitted_traces = pm4py.convert_to_event_log(fitted_traces)
        if len(fitted_traces):
    
            # # Group by 'case:concept:name' and apply the penalization
            # penalized_traces_log = fitted_traces.groupby('case:concept:name').apply(lambda group: penalize_trace(group, routines[pattern_label]))
            
            # # Reset index for better readability
            # penalized_traces_log.reset_index(drop=True, inplace=True)
    
            JC_scores = {}
            # print("\n")
            # print("="*150)
            for file_name in os.listdir(cpn_ground_truth_dir):
                model_name = file_name.split('.')[0]
                cpn_ground_truth_path = os.path.join(cpn_ground_truth_dir, file_name)
                gt_net, gt_im, gt_fm = pnml_importer.import_net(cpn_ground_truth_path)
                JC = get_JC(gt_net, gt_im, gt_fm, routine_label=pattern_label)
                JC_scores[file_name] = JC
                # print(f"JC Score of {pattern_label} is {JC} with {model_name}")
                # print("="*150)
                # print("\n")
            # Find the key with the maximum value
            max_key = max(JC_scores, key=JC_scores.get)
            max_value = JC_scores[max_key]
        
            # Output the result
            # print(f"\nMaximum JC Score of {pattern_label} is {max_value}")
    
            cpn_ground_truth_path = os.path.join(cpn_ground_truth_dir, max_key)
            gt_net, gt_im, gt_fm = pnml_importer.import_net(cpn_ground_truth_path)
            scores = evaluate_routines(fitted_traces, gt_net, gt_im, gt_fm, token_base=False, routine_label=pattern_label)
            result_dic[key_value] = scores
            key_value += 1
        else:
            JC_scores = {}
            # print("\n")
            # print("="*150)
            for file_name in os.listdir(cpn_ground_truth_dir):
                model_name = file_name.split('.')[0]
                cpn_ground_truth_path = os.path.join(cpn_ground_truth_dir, file_name)
                gt_net, gt_im, gt_fm = pnml_importer.import_net(cpn_ground_truth_path)
                JC = get_JC(gt_net, gt_im, gt_fm, routine_label=pattern_label)
                JC_scores[file_name] = JC
                # print(f"JC Score of {pattern_label} is {JC} with {model_name}")
                # print("="*150)
                # print("\n")
    
            # Find the key with the maximum value
            max_key = max(JC_scores, key=JC_scores.get)
            max_value = JC_scores[max_key]
        
            # Output the result
            # print(f"\nMaximum JC Score of {pattern_label} is {max_value}")
            
            scores = [pattern_label, 0, len(routines[pattern_label]), 0, 0, 0, 0, 0, 0, 0, max_value]
            result_dic[key_value] = scores
            key_value += 1

# %% [markdown]
# ## *Summary of Evaluation Scores*

# %%
# # Initialize a list for the average values
# average_values = ["Average"]

# # Calculate the sum of Traces for weighted calculations and add as a separate metric
# total_traces = sum(result_dic[key][1] for key in result_dic if isinstance(key, int))
# average_values.append(total_traces)  # Sum of Traces (instead of an average)

# # Calculate averages and weighted means for each metric column
# for i in range(2, len(result_dic[1])):  # Start from index 2 to skip Routine and Traces
#     values = [result_dic[key][i] for key in result_dic if isinstance(key, int)]
    
#     if i in [9, 10, 11]:  # For Coverage, Support, and JC indices
#         # Calculate weighted mean
#         weighted_mean = sum(result_dic[key][i] * result_dic[key][1] for key in result_dic if isinstance(key, int)) / total_traces
#         average_values.append(weighted_mean)
#     else:
#         # For other metrics, calculate a simple average
#         avg = sum(values) / len(values)
#         average_values.append(avg)

# # Find the next available numeric key
# next_key = max([key for key in result_dic if isinstance(key, int)]) + 1

# # Add the new row to result_dic with the calculated averages
# result_dic[next_key] = average_values

# %%
# # Initialize two lists for average values
# simple_average_values = ["Simple Average"]
# weighted_average_values = ["Weighted Average"]

# # Calculate the sum of Traces for weighted calculations
# total_traces = sum(result_dic[key][1] for key in result_dic if isinstance(key, int))

# # Append the total traces to both average rows
# simple_average_values.append(total_traces)  # Sum of Traces for simple average
# weighted_average_values.append(total_traces)  # Sum of Traces for weighted average

# # Calculate averages for each metric column
# for i in range(2, len(result_dic[1])):  # Start from index 2 to skip Routine and Traces
#     values = [result_dic[key][i] for key in result_dic if isinstance(key, int)]

#     if i == 2:
#         # Special case: Simple average for trace length (index 2)
#         simple_avg = sum(values) / len(values)
#         weighted_avg = simple_avg  # Use the same for weighted average
#     else:
#         # Simple average for other metrics
#         simple_avg = sum(values) / len(values)
        
#         # Weighted average for other metrics
#         weighted_avg = sum(result_dic[key][i] * result_dic[key][1] for key in result_dic if isinstance(key, int)) / total_traces

#     # Append the averages to the respective lists
#     simple_average_values.append(simple_avg)
#     weighted_average_values.append(weighted_avg)

# # Find the next available numeric keys
# next_key_simple = max([key for key in result_dic if isinstance(key, int)]) + 1
# next_key_weighted = next_key_simple + 1

# # Add the new rows to result_dic
# result_dic[next_key_simple] = simple_average_values
# result_dic[next_key_weighted] = weighted_average_values

# %%
# result_df = pd.DataFrame(result_dic)
# result_df = result_df.set_index('Metrics')
# # displaying the DataFrame
# print(tabulate(result_df.T, headers = 'keys', tablefmt = 'psql'))
# # result_df.T

# %%
# ✅ Function to calculate F-score given fitness and precision
def calculate_f_score(fitness, precision):
    if fitness + precision == 0:
        return 0
    return 2 * (fitness * precision) / (fitness + precision)

# ✅ Function to calculate simple and weighted averages for a single result dictionary
def UI_logs_summary(result_dic):
    # Column names including Coverage, Support, and JC
    columns = ["Metrics", "Traces", "Trace Length", "Fitness", "Precision", 
               "Generalization", "Simplicity", "F-Score", "Coverage", "Support", "JC"]

    # Initialize lists for averages
    simple_average_values = ["Simple Average"]
    weighted_average_values = ["Weighted Average"]

    total_traces = sum(result_dic[key][1] for key in result_dic if isinstance(key, int))
    simple_average_values.append(total_traces)
    weighted_average_values.append(total_traces)

    mean_fitness = mean_precision = weighted_fitness = weighted_precision = 0

    # Iterate through metrics starting from index 2 ("Trace Length")
    for i in range(2, len(result_dic[1])):  
        values = [result_dic[key][i] for key in result_dic if isinstance(key, int)]

        simple_avg = sum(values) / len(values)
        weighted_avg = sum(result_dic[key][i] * result_dic[key][1] for key in result_dic if isinstance(key, int)) / total_traces

        simple_avg = round(simple_avg, 3)
        weighted_avg = round(weighted_avg, 3)
        
        if i == 3:  # Fitness column
            mean_fitness = simple_avg
            weighted_fitness = weighted_avg
        elif i == 4:  # Precision column
            mean_precision = simple_avg
            weighted_precision = weighted_avg

        simple_average_values.append(simple_avg)
        weighted_average_values.append(weighted_avg)

    # 🔢 Calculate and update the F-Score
    f_score_simple_avg = calculate_f_score(mean_fitness, mean_precision)
    f_score_weighted_avg = calculate_f_score(weighted_fitness, weighted_precision)

    # Update F-Score at the correct index (7th metric after 'Metrics' & 'Traces')
    simple_average_values[7] = round(f_score_simple_avg, 3)
    weighted_average_values[7] = round(f_score_weighted_avg, 3)

    # ➕ Insert average rows into result_dic
    next_key_simple = max([key for key in result_dic if isinstance(key, int)], default=0) + 1
    next_key_weighted = next_key_simple + 1

    result_dic[next_key_simple] = simple_average_values
    result_dic[next_key_weighted] = weighted_average_values

    # 📝 Convert to DataFrame and print
    result_df = pd.DataFrame.from_dict(result_dic, orient='index', columns=columns)
    result_df = result_df.set_index('Metrics')

    # print("\n✅ Per-Log Summary:")
    # print(tabulate(result_df, headers='keys', tablefmt='psql'))

    return result_dic, simple_average_values  # Return simple average row for aggregation

# 🚀 Function to handle cross-validation and final aggregation
def cross_validation_summary(cross_val_results):
    """Performs cross-validation, collects simple averages, and calculates final averages."""
    iter_results = {}
    simple_averages_list = []

    # 📊 Collect simple averages from each iteration
    for i, result_dic in enumerate(cross_val_results, start=1):
        _, simple_avg_row = UI_logs_summary(result_dic)
        iter_results[f"CV {i}"] = simple_avg_row[1:]  # Exclude 'Simple Average' label
        simple_averages_list.append(simple_avg_row[1:])

    # 🔎 Convert iteration results into DataFrame
    iter_columns = ["Traces", "Trace Length", "Fitness", "Precision", "Gen", 
                    "Simp", "F-Score", "Coverage", "Support", "JC"]
    iter_df = pd.DataFrame(iter_results, index=iter_columns).T

    print("\n✅ Cross-Validation Iteration Results:")
    print(tabulate(iter_df, headers='keys', tablefmt='psql'))

    # 🧮 Final Simple and Weighted Averages
    final_simple_avg = iter_df.mean().tolist()
    total_traces = iter_df["Traces"].sum()
    weighted_avg = [(iter_df[col] * iter_df["Traces"]).sum() / total_traces for col in iter_df.columns]

    # 📢 Final Aggregated Results
    final_df = pd.DataFrame(
        [final_simple_avg, weighted_avg],
        index=["Simple Average", "Weighted Average"],
        columns=iter_columns
    )

    print("\n🚀 Final Aggregated Results:")
    print(tabulate(final_df, headers='keys', tablefmt='outline'))

    return iter_df, final_df

# %% [markdown]
# ## *main*

# %%
noise_prob = 0.1

for log_number in range(3, 6):
    cross_val_results = []
    for variant in range(1, 11):
        try:
            log_path = f"Transformed_Logs_and_Results/Our/Transformed_Log_With_Noise_{noise_prob}/log{log_number}/noisy_transform_log{log_number}_{variant}.xes"
            routines_file_path = f"Transformed_Logs_and_Results/Simon/Transformed_Log_With_Noise_{noise_prob}/log{log_number}/simon_noisy_transform_log{log_number}_{variant}_.txt"
            cpn_ground_truth_dir = f"GT_Models/log{log_number}/"
        
            result_dic = {'Metrics':['Routine', "Traces", "Length", 'Fitness','Precision','Generalization','Simplicity', 'F_Score', 'coverage', 'Support', 'JC'],}
            
            log, reference_set = UI_read_log(log_path)
            all_routines = read_routines(routines_file_path)
            routine_vectors, routines = get_discover_routines_encoding(all_routines=all_routines, reference_set=reference_set)
            
            session_log = f.create_session(log)
            encoded_log = freq_encoding(session_log)
            
            # Assign labels
            encoded_log = assign_labels_by_distance(encoded_log, routine_vectors, reference_set)
            activity_log = assign_pattern_to_traces(session_log, encoded_log)
            
            result_dict = routines_evaluate(activity_log, routine_vectors, routines)
            cross_val_results.append(result_dic)
        except Exception as e:
            print(f"Error encountered for Log{log_number}, Variant {variant}: {e}")
            continue  # Continue with the next variant
    
    # Run cross-validation summary
    iteration_results, final_averages = cross_validation_summary(cross_val_results)
    results_df = pd.concat([iteration_results, final_averages])
    
    outputfile = f"Transformed_Logs_and_Results/Simon/Transformed_Log_With_Noise_{noise_prob}/Results"
    if not os.path.exists(outputfile):
        os.makedirs(outputfile)
    output_file_name = f"log{log_number}_reuslts.csv"
    results_df.to_csv(os.path.join(outputfile, output_file_name))
# Out:
# parsing log, completed traces :: 100%|████████████████████████████████████████████| 1000/1000 [00:01<00:00, 557.08it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 9/9 [00:00<00:00, 94.64it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 9/9 [00:00<00:00, 902.50it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 78/78 [00:00<00:00, 1403.97it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 104.99it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1001.35it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 1600.91it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 2205.00it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 22/22 [00:00<00:00, 143.24it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 22/22 [00:00<00:00, 774.55it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 148/148 [00:00<00:00, 2710.55it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 70/70 [00:00<00:00, 93.65it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 70/70 [00:00<00:00, 635.32it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 699/699 [00:00<00:00, 1911.15it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 115.20it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1001.51it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 1823.21it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 5/5 [00:00<00:00, 161.69it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 557.03it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 30/30 [00:00<00:00, 1394.24it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 17/17 [00:00<00:00, 72.32it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 17/17 [00:00<00:00, 482.19it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 264/264 [00:00<00:00, 1956.27it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 6/6 [00:00<00:00, 117.47it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 601.59it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 2810.43it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 2605.53it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 21/21 [00:00<00:00, 181.03it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 21/21 [00:00<00:00, 575.77it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 192/192 [00:00<00:00, 2638.27it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 125.34it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.05it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 29/29 [00:00<00:00, 1890.09it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████████████| 14/14 [00:00<?, ?it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 3309.23it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 103.39it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 643.11it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 45/45 [00:00<00:00, 2912.67it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 43/43 [00:00<00:00, 230.56it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 43/43 [00:00<00:00, 1105.46it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 259/259 [00:00<00:00, 2677.26it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 4010.33it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 105.54it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 802.47it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 45/45 [00:00<00:00, 3007.96it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 4/4 [00:00<00:00, 80.72it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 501.14it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 42/42 [00:00<00:00, 2540.72it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 56/56 [00:00<00:00, 141.22it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 56/56 [00:00<00:00, 805.50it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 374/374 [00:00<00:00, 1976.78it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 23/23 [00:00<00:00, 153.03it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 23/23 [00:00<00:00, 633.44it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 151/151 [00:00<00:00, 777.91it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 9/9 [00:00<00:00, 3007.63it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 10/10 [00:00<00:00, 189.15it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 10/10 [00:00<00:00, 771.30it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 50/50 [00:00<00:00, 2383.24it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 187.52it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.52it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 1837.99it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 6/6 [00:00<00:00, 140.01it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 752.14it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 25/25 [00:00<00:00, 1795.20it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 3672.19it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 3/3 [00:00<00:00, 76.09it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 246.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 31/31 [00:00<00:00, 2825.92it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 246.55it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1000.67it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 1337.31it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 13/13 [00:00<00:00, 129.09it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 13/13 [00:00<00:00, 624.42it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 103/103 [00:00<00:00, 2625.25it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 17/17 [00:00<00:00, 114.07it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 17/17 [00:00<00:00, 616.11it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 131/131 [00:00<00:00, 2365.59it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 1253.49it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 76.14it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 1002.63it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 12/12 [00:00<00:00, 144.89it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 12/12 [00:00<00:00, 689.78it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 93/93 [00:00<00:00, 1989.65it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 9/9 [00:00<00:00, 137.15it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 9/9 [00:00<00:00, 691.36it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 1455.04it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 128.88it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 572.19it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 46/46 [00:00<00:00, 1919.00it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 5/5 [00:00<00:00, 2502.87it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 2271.49it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 5/5 [00:00<00:00, 107.01it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 757.29it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 68/68 [00:00<00:00, 1886.33it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 1145.63it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 1836.82it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 5/5 [00:00<00:00, 222.18it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 311.58it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 24/24 [00:00<00:00, 1604.58it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 120.08it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 316.04it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 72/72 [00:00<00:00, 1746.18it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 8/8 [00:00<00:00, 178.24it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 8/8 [00:00<00:00, 729.25it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 69/69 [00:00<00:00, 2033.68it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 10/10 [00:00<00:00, 100.26it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 10/10 [00:00<00:00, 527.74it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 110/110 [00:00<00:00, 2150.72it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 156.30it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1003.01it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 64/64 [00:00<00:00, 1833.49it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 1574.76it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 2512.46it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 182.33it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.89it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 1604.36it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 3/3 [00:00<00:00, 91.24it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 463.90it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 36/36 [00:00<00:00, 1284.98it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 10/10 [00:00<00:00, 125.20it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 10/10 [00:00<00:00, 527.41it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 52/52 [00:00<00:00, 1291.02it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 225.43it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1002.34it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2671.74it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 182.37it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 22/22 [00:00<00:00, 1490.01it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 71.32it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 292.47it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 20/20 [00:00<00:00, 668.43it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 6/6 [00:00<00:00, 60.19it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 743.03it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 59/59 [00:00<00:00, 4227.05it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 125.33it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 330.23it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 1114.11it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 5/5 [00:00<00:00, 133.95it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 630.12it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 56/56 [00:00<00:00, 1051.75it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 91.15it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.29it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 28/28 [00:00<00:00, 2607.65it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 125.34it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 28/28 [00:00<00:00, 1339.04it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 94.82it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.23it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 28/28 [00:00<00:00, 4881.96it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 15/15 [00:00<00:00, 4720.48it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 14/14 [00:00<00:00, 139.32it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 561.51it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 118/118 [00:00<00:00, 1278.44it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 250.47it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 1179.73it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 14/14 [00:00<00:00, 113.71it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 701.95it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 141/141 [00:00<00:00, 1790.33it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 3329.87it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 104.91it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 540.15it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 90/90 [00:00<00:00, 3065.22it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 12/12 [00:00<00:00, 79.51it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 12/12 [00:00<00:00, 414.16it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 111/111 [00:00<00:00, 1315.24it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 8/8 [00:00<00:00, 115.19it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 8/8 [00:00<00:00, 572.95it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 91/91 [00:00<00:00, 1516.45it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 25/25 [00:00<00:00, 2279.12it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 10/10 [00:00<00:00, 119.47it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 10/10 [00:00<00:00, 655.54it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 145/145 [00:00<00:00, 1821.26it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 9/9 [00:00<00:00, 97.27it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 9/9 [00:00<00:00, 753.75it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 87/87 [00:00<00:00, 639.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 1813.36it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 154.26it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.29it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 2607.15it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 2673.23it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 26/26 [00:00<00:00, 60.80it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 26/26 [00:00<00:00, 457.49it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 401/401 [00:00<00:00, 1549.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 1711.03it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 117.97it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 547.38it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 29/29 [00:00<00:00, 1530.32it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 5/5 [00:00<00:00, 161.77it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 716.36it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 26/26 [00:00<00:00, 3258.49it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 2605.03it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 1634.06it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 104.67it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 401.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 30/30 [00:00<00:00, 1583.25it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 143.25it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.47it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 19/19 [00:00<00:00, 6351.46it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 14/14 [00:00<00:00, 169.61it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 947.64it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 147/147 [00:00<00:00, 2256.77it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 3674.53it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 3/3 [00:00<00:00, 95.65it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 429.76it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 29/29 [00:00<00:00, 1454.07it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 15/15 [00:00<00:00, 72.50it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 370.01it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 199/199 [00:00<00:00, 1988.25it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 14/14 [00:00<00:00, 1754.20it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 105.54it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.44it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 21/21 [00:00<00:00, 758.70it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 8/8 [00:00<00:00, 67.70it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 8/8 [00:00<00:00, 506.27it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 80/80 [00:00<00:00, 978.00it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 4/4 [00:00<00:00, 98.98it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 501.26it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 42/42 [00:00<00:00, 1227.21it/s]
# parsing log, completed traces :: 100%|████████████████████████████████████████████| 1000/1000 [00:01<00:00, 558.79it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 40/40 [00:00<00:00, 131.61it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 40/40 [00:00<00:00, 691.41it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 284/284 [00:00<00:00, 1741.23it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 141.81it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 244.41it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 18/18 [00:00<00:00, 1388.38it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 12/12 [00:00<00:00, 61.57it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 12/12 [00:00<00:00, 573.00it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 143/143 [00:00<00:00, 1540.27it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 15/15 [00:00<00:00, 129.77it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 304.95it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 99/99 [00:00<00:00, 1046.83it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 6/6 [00:00<00:00, 80.61it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 375.98it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 64/64 [00:00<00:00, 776.37it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 105.55it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.57it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 1985.00it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 15/15 [00:00<00:00, 115.29it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 752.02it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 81/81 [00:00<00:00, 2461.14it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 18/18 [00:00<00:00, 121.13it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 18/18 [00:00<00:00, 902.46it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 137/137 [00:00<00:00, 2409.96it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 54/54 [00:00<00:00, 212.78it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 54/54 [00:00<00:00, 1002.68it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 280/280 [00:00<00:00, 2387.23it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 17/17 [00:00<00:00, 97.64it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 17/17 [00:00<00:00, 774.83it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 113/113 [00:00<00:00, 821.99it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 176.01it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 200.50it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 1691.12it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 12/12 [00:00<00:00, 123.25it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 12/12 [00:00<00:00, 751.97it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 90/90 [00:00<00:00, 4097.78it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 9/9 [00:00<00:00, 267.77it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 9/9 [00:00<00:00, 751.91it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 40/40 [00:00<00:00, 3341.81it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 1629.20it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 14/14 [00:00<00:00, 125.65it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 935.83it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 101/101 [00:00<00:00, 1486.15it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 117.52it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 376.00it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 21/21 [00:00<00:00, 2631.86it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 111.68it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 376.02it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 40/40 [00:00<00:00, 2455.90it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 121.40it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 584.92it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 58/58 [00:00<00:00, 1137.66it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 19/19 [00:00<00:00, 91.28it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 19/19 [00:00<00:00, 481.54it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 104/104 [00:00<00:00, 769.91it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 2206.26it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 11/11 [00:00<00:00, 121.61it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 11/11 [00:00<00:00, 393.90it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 108/108 [00:00<00:00, 498.94it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 3207.57it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 1604.48it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 117.22it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 572.89it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 54/54 [00:00<00:00, 1497.30it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 133.69it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 401.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 30/30 [00:00<00:00, 1672.75it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 2131.44it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 1448.08it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 120.80it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 501.70it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 72/72 [00:00<00:00, 1640.74it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 11/11 [00:00<00:00, 543.84it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 157.38it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 2006.36it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 14/14 [00:00<00:00, 2005.88it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 6/6 [00:00<00:00, 184.51it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 501.35it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 30/30 [00:00<00:00, 2428.10it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 66.10it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.41it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 23/23 [00:00<00:00, 3157.33it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 250.58it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 307.34it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 797.78it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 953.10it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 10/10 [00:00<00:00, 126.76it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 10/10 [00:00<00:00, 775.88it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 82/82 [00:00<00:00, 1304.21it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 14/14 [00:00<00:00, 75.15it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 561.57it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 116/116 [00:00<00:00, 1507.32it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 5015.01it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 11/11 [00:00<00:00, 107.81it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 11/11 [00:00<00:00, 787.70it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 108/108 [00:00<00:00, 1754.90it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 1894.14it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 75/75 [00:00<00:00, 91.25it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 75/75 [00:00<00:00, 567.46it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 798/798 [00:00<00:00, 1821.84it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 15/15 [00:00<00:00, 1879.45it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 125.33it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 334.31it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 5687.87it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 34/34 [00:00<00:00, 57.67it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 34/34 [00:00<00:00, 480.16it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 547/547 [00:00<00:00, 1958.82it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 7/7 [00:00<00:00, 97.48it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1003.08it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 63/63 [00:00<00:00, 1663.10it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 14/14 [00:00<00:00, 119.98it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 14/14 [00:00<00:00, 701.91it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 150/150 [00:00<00:00, 1973.46it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 31/31 [00:00<00:00, 57.37it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 31/31 [00:00<00:00, 634.37it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 385/385 [00:00<00:00, 2253.52it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 202.56it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 572.95it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 23/23 [00:00<00:00, 3294.82it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 4/4 [00:00<00:00, 59.86it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 489.93it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 39/39 [00:00<00:00, 722.55it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 2246.77it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 15/15 [00:00<00:00, 90.63it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 626.67it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 173/173 [00:00<00:00, 2627.66it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 6/6 [00:00<00:00, 83.20it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 6/6 [00:00<00:00, 859.55it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 54/54 [00:00<00:00, 2048.35it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 41/41 [00:00<00:00, 189.60it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 41/41 [00:00<00:00, 691.32it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 308/308 [00:00<00:00, 2262.80it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 16/16 [00:00<00:00, 69.79it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 16/16 [00:00<00:00, 682.78it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 166/166 [00:00<00:00, 956.99it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 5/5 [00:00<00:00, 62.67it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 5/5 [00:00<00:00, 224.15it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 57/57 [00:00<00:00, 1843.55it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 1838.29it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 4/4 [00:00<00:00, 79.13it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 668.55it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 26/26 [00:00<00:00, 1086.33it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 15/15 [00:00<00:00, 110.30it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 15/15 [00:00<00:00, 460.56it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 141/141 [00:00<00:00, 2110.10it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 64.69it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 668.15it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 28/28 [00:00<00:00, 2005.44it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 4/4 [00:00<00:00, 49.52it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 308.50it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 66/66 [00:00<00:00, 1161.01it/s]
# parsing log, completed traces :: 100%|████████████████████████████████████████████| 1000/1000 [00:02<00:00, 495.01it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████| 159/159 [00:01<00:00, 128.77it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████| 159/159 [00:00<00:00, 848.74it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 966/966 [00:00<00:00, 1301.38it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 120.37it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 501.55it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 40/40 [00:00<00:00, 1792.63it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 2/2 [00:00<00:00, 91.20it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 400.54it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 28/28 [00:00<00:00, 3124.50it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2674.30it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 18/18 [00:00<00:00, 124.47it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 18/18 [00:00<00:00, 842.02it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 177/177 [00:00<00:00, 1706.41it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 12/12 [00:00<00:00, 1413.61it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 2338.71it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 9/9 [00:00<00:00, 4502.47it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 3/3 [00:00<00:00, 84.21it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 429.69it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 26/26 [00:00<00:00, 573.00it/s]
# aligning log, completed variants :: 100%|████████████████████████████████████████████████| 7/7 [00:00<00:00, 92.52it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 7/7 [00:00<00:00, 371.37it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 60/60 [00:00<00:00, 1353.72it/s]
# aligning log, completed variants :: 100%|██████████████████████████████████████████████| 29/29 [00:00<00:00, 49.96it/s]
# replaying log with TBR, completed variants :: 100%|███████████████████████████████████| 29/29 [00:00<00:00, 475.40it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████| 480/480 [00:00<00:00, 1935.78it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 133.66it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 501.41it/s]
# ...
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 752.25it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 15/15 [00:00<00:00, 1253.38it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1103.39it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 209.38it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1170.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 25/25 [00:00<00:00, 3133.26it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 200.46it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 666.87it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 12/12 [00:00<00:00, 1718.62it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 1505.13it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 286.45it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1002.70it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 2759.58it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 4012.73it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 222.80it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 2006.60it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 19/19 [00:00<00:00, 4767.11it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 143.31it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 751.08it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 15/15 [00:00<00:00, 3760.13it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3007.75it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 2005.40it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 222.84it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 1337.26it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 3409.68it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 176.96it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1503.51it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 3258.78it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 334.19it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 1536.94it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2004.69it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 2004.45it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 9/9 [00:00<00:00, 3006.43it/s]
# aligning log, completed variants :: 100%|█████████████████████████████████████████████| 11/11 [00:00<00:00, 218.06it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 1378.96it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 47/47 [00:00<00:00, 2356.44it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3008.83it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 200.57it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1504.77it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 12/12 [00:00<00:00, 1884.66it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2005.76it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3009.91it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 2342.25it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 7/7 [00:00<00:00, 194.97it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1753.47it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 22/22 [00:00<00:00, 2208.80it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 4/4 [00:00<00:00, 250.62it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 4/4 [00:00<00:00, 802.24it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 1967.20it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3008.47it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 3506.11it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 167.13it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1002.10it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 12/12 [00:00<00:00, 2405.80it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 5/5 [00:00<00:00, 2505.56it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 1604.55it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 200.51it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1003.66it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 22/22 [00:00<00:00, 3677.16it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2005.40it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 3993.19it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 1423.97it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 233.34it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 2006.84it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 14/14 [00:00<00:00, 2807.30it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 11/11 [00:00<00:00, 2206.26it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 5/5 [00:00<00:00, 2507.36it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2675.37it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 8/8 [00:00<00:00, 2673.66it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 2001.82it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 1671.30it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 3511.98it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 133.69it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1002.94it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 17/17 [00:00<00:00, 1704.72it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3003.44it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 250.69it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1001.27it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 2607.28it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 9/9 [00:00<00:00, 4517.56it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 105.55it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 143.24it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 20/20 [00:00<00:00, 1114.16it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 200.55it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1503.51it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 22/22 [00:00<00:00, 2206.00it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 2006.68it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 125.80it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 2/2 [00:00<00:00, 500.81it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 14/14 [00:00<00:00, 1559.06it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 4/4 [00:00<00:00, 1527.01it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 2005.24it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 204.51it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 2003.49it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 13/13 [00:00<00:00, 2607.28it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 182.00it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1003.06it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1756.20it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 2/2 [00:00<00:00, 286.57it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 2/2 [00:00<00:00, 1001.62it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 2005.31it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 273.48it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 3/3 [00:00<00:00, 1503.51it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 14/14 [00:00<00:00, 3509.04it/s]
# aligning log, completed variants :: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 126.88it/s]
# replaying log with TBR, completed variants :: 100%|█████████████████████████████████████| 3/3 [00:00<00:00, 752.16it/s]
# replaying log with TBR, completed variants :: 100%|██████████████████████████████████| 10/10 [00:00<00:00, 2504.21it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 7/7 [00:00<00:00, 1372.03it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 3009.19it/s]
# replaying log with TBR, completed variants :: 100%|████████████████████████████████████| 6/6 [00:00<00:00, 5993.29it/s]
# ✅ Cross-Validation Iteration Results:
# +-------+----------+----------------+-----------+-------------+-------+--------+-----------+------------+-----------+-------+
# |       |   Traces |   Trace Length |   Fitness |   Precision |   Gen |   Simp |   F-Score |   Coverage |   Support |    JC |
# |-------+----------+----------------+-----------+-------------+-------+--------+-----------+------------+-----------+-------|
# | CV 1  |     1000 |          6.329 |     0.256 |       0.241 | 0.126 |  0.301 |     0.248 |      0.301 |     0.271 | 0.648 |
# | CV 2  |     1000 |          6.39  |     0.276 |       0.256 | 0.133 |  0.323 |     0.266 |      0.323 |     0.29  | 0.652 |
# | CV 3  |     1000 |          6.509 |     0.274 |       0.244 | 0.128 |  0.321 |     0.258 |      0.321 |     0.29  | 0.659 |
# | CV 4  |     1000 |          6.654 |     0.261 |       0.24  | 0.126 |  0.308 |     0.25  |      0.308 |     0.277 | 0.649 |
# | CV 5  |     1000 |          6.389 |     0.236 |       0.211 | 0.122 |  0.281 |     0.223 |      0.281 |     0.256 | 0.654 |
# | CV 6  |     1000 |          6.498 |     0.283 |       0.251 | 0.126 |  0.336 |     0.266 |      0.336 |     0.296 | 0.653 |
# | CV 7  |     1000 |          6.274 |     0.27  |       0.241 | 0.13  |  0.323 |     0.255 |      0.323 |     0.289 | 0.643 |
# | CV 8  |     1000 |          6.385 |     0.295 |       0.265 | 0.14  |  0.351 |     0.279 |      0.351 |     0.315 | 0.648 |
# | CV 9  |     1000 |          6.255 |     0.257 |       0.238 | 0.124 |  0.301 |     0.247 |      0.301 |     0.273 | 0.645 |
# | CV 10 |     1000 |          6.454 |     0.286 |       0.26  | 0.135 |  0.337 |     0.272 |      0.337 |     0.299 | 0.653 |
# +-------+----------+----------------+-----------+-------------+-------+--------+-----------+------------+-----------+-------+
#
# 🚀 Final Aggregated Results:
# +------------------+----------+----------------+-----------+-------------+-------+--------+-----------+------------+-----------+--------+
# |                  |   Traces |   Trace Length |   Fitness |   Precision |   Gen |   Simp |   F-Score |   Coverage |   Support |     JC |
# +==================+==========+================+===========+=============+=======+========+===========+============+===========+========+
# | Simple Average   |     1000 |         6.4137 |    0.2694 |      0.2447 | 0.129 | 0.3182 |    0.2564 |     0.3182 |    0.2856 | 0.6504 |
# | Weighted Average |     1000 |         6.4137 |    0.2694 |      0.2447 | 0.129 | 0.3182 |    0.2564 |     0.3182 |    0.2856 | 0.6504 |
# +------------------+----------+----------------+-----------+-------------+-------+--------+-----------+------------+-----------+--------+
